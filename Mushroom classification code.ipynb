# %%
#mushroom data set classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-319bf97a-4051-46d2-b173-ceceaf677f20" name="files[]" multiple disabled />
#      <output id="result-319bf97a-4051-46d2-b173-ceceaf677f20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mushrooms.csv to mushrooms.csv
# ...

# %%
m_data=pd.read_csv('mushrooms.csv')

# %%
data=m_data.copy() #making a copy of data

# %%
data.head()
# Out:
#   class cap-shape cap-surface  ... spore-print-color population habitat
# 0     p         x           s  ...                 k          s       u
# 1     e         x           s  ...                 n          n       g
# 2     e         b           s  ...                 n          n       m
# 3     p         x           y  ...                 k          s       u
# 4     e         x           s  ...                 n          a       g
#
# [5 rows x 23 columns]

# %%
data.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
data.shape
# Out:
# (8124, 23)

# %%
data.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# Checking unique values

# %%
data['bruises'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %%
data['cap-color'].unique()
# Out:
# array(['n', 'y', 'w', 'g', 'e', 'p', 'b', 'u', 'c', 'r'], dtype=object)

# %%
data['cap-shape'].unique()
# Out:
# array(['x', 'b', 's', 'f', 'k', 'c'], dtype=object)

# %%
data['cap-surface'].unique()
# Out:
# array(['s', 'y', 'f', 'g'], dtype=object)

# %%
data['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
data['gill-attachment'].unique()
# Out:
# array(['f', 'a'], dtype=object)

# %%
data['gill-color'].unique()
# Out:
# array(['k', 'n', 'g', 'p', 'w', 'h', 'u', 'e', 'b', 'r', 'y', 'o'],
#       dtype=object)

# %%
data['gill-size'].unique()
# Out:
# array(['n', 'b'], dtype=object)

# %%
data['gill-spacing'].unique()
# Out:
# array(['c', 'w'], dtype=object)

# %%
data['habitat'].unique()
# Out:
# array(['u', 'g', 'm', 'd', 'p', 'w', 'l'], dtype=object)

# %%
data['odor'].unique()
# Out:
# array(['p', 'a', 'l', 'n', 'f', 'c', 'y', 's', 'm'], dtype=object)

# %%
data['population'].unique()
# Out:
# array(['s', 'n', 'a', 'v', 'y', 'c'], dtype=object)

# %%
data['ring-number'].unique()
# Out:
# array(['o', 't', 'n'], dtype=object)

# %%
data['ring-type'].unique()
# Out:
# array(['p', 'e', 'l', 'f', 'n'], dtype=object)

# %%
data['spore-print-color'].unique()
# Out:
# array(['k', 'n', 'u', 'h', 'w', 'r', 'o', 'y', 'b'], dtype=object)

# %%
data['stalk-color-above-ring'].unique()
# Out:
# array(['w', 'g', 'p', 'n', 'b', 'e', 'o', 'c', 'y'], dtype=object)

# %%
data['stalk-color-below-ring'].unique()
# Out:
# array(['w', 'p', 'g', 'b', 'n', 'e', 'y', 'o', 'c'], dtype=object)

# %%
data['stalk-root'].unique()  # special caharcters are present here
# Out:
# array(['e', 'c', 'b', 'r', '?'], dtype=object)

# %%
data['stalk-shape'].unique()
# Out:
# array(['e', 't'], dtype=object)

# %%
data['stalk-surface-above-ring'].unique()
# Out:
# array(['s', 'f', 'k', 'y'], dtype=object)

# %%
data['stalk-surface-below-ring'].unique()
# Out:
# array(['s', 'f', 'y', 'k'], dtype=object)

# %%
data['veil-color'].unique()
# Out:
# array(['w', 'n', 'o', 'y'], dtype=object)

# %%
data['veil-type'].unique()  # so we can drop veil type since it has only one value for all instances
# Out:
# array(['p'], dtype=object)

# %%
data['stalk-root'].value_counts()
# Out:
# b    3776
# ?    2480
# e    1120
# c     556
# r     192
# Name: stalk-root, dtype: int64

# %%
x =  data['class']
ax = sns.countplot(x=x,data=data) 
#balanced data set with an almost equal number of poisonous and edible mushrooms

# %% [markdown]
# Bar plot of all possible values separated by the class of mushroom for each feature(The hue will give a color code to the poisonous and edible class)

# %%
def plot_data(hue,data):
  for i,col in enumerate(data.columns):
    plt.figure(i) 
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    ax=sns.countplot(x=data[col],hue=hue,data=data)

# %%
hue= data['class']
data_for_plot= data.drop('class',1)
plot_data(hue,data_for_plot)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data['stalk-root']=data['stalk-root'].replace('?','b') # replacing all the '?' to the mode value 'b'

# %%
data['stalk-root'].value_counts()
# Out:
# b    6256
# e    1120
# c     556
# r     192
# Name: stalk-root, dtype: int64

# %%
data.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
data.head()
# Out:
#   class cap-shape cap-surface  ... spore-print-color population habitat
# 0     p         x           s  ...                 k          s       u
# 1     e         x           s  ...                 n          n       g
# 2     e         b           s  ...                 n          n       m
# 3     p         x           y  ...                 k          s       u
# 4     e         x           s  ...                 n          a       g
#
# [5 rows x 23 columns]

# %%
data.drop(columns=['veil-type'],inplace= True)

# %%
data.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
categorical_columns = ['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring','veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']
sdata= pd.get_dummies(data,columns=categorical_columns)
sdata.dtypes
sdata.iloc[4:8]
# Out:
#   class  cap-shape_b  cap-shape_c  ...  habitat_p  habitat_u  habitat_w
# 4     e            0            0  ...          0          0          0
# 5     e            0            0  ...          0          0          0
# 6     e            1            0  ...          0          0          0
# 7     e            1            0  ...          0          0          0
#
# [4 rows x 116 columns]

# %%
sdata.shape
# Out:
# (8124, 116)

# %%
sdata['class']=sdata['class'].map({'p':0, 'e':1})

# %%
X = sdata.iloc[:,sdata.columns !='class']
y = sdata.iloc[:,sdata.columns =='class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
#LOGISTIC REGRESSION

from sklearn.linear_model import LogisticRegression
classifier1= LogisticRegression(random_state=42,solver='lbfgs')
classifier1.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_logistic = classifier1.predict(X_test)

# %%
Accuracy_values=[]
fscore=[]
from sklearn.metrics import precision_score,recall_score,f1_score,accuracy_score
print('Precision is:',precision_score(y_test,y_pred_logistic))
print('F score is:',f1_score(y_test,y_pred_logistic))
print('accuracy is:',accuracy_score(y_test,y_pred_logistic))
Accuracy_values=[{'Logistic':accuracy_score(y_test,y_pred_logistic)}]
fscore=[{'Logistic':f1_score(y_test,y_pred_logistic)}]
# Out:
# Precision is: 1.0
# F score is: 1.0
# accuracy is: 1.0

# %%
#SVM
from sklearn.svm import SVC
classifier2= SVC(kernel = 'rbf' ,random_state= 0)
classifier2.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=0,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred_svm = classifier2.predict(X_test)
print('Precision is:',precision_score(y_test,y_pred_svm))
print('F score is:',f1_score(y_test,y_pred_svm))
print('accuracy i s:',accuracy_score(y_test,y_pred_svm))
Accuracy_values.append({'SVM':accuracy_score(y_test,y_pred_svm)})
fscore.append({'SVM':f1_score(y_test,y_pred_svm)})
# Out:
# Precision is: 0.9968279143536876
# F score is: 0.9984114376489277
# accuracy i s: 0.9983593109105825

# %%
# RandomForest
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(X_train,y_train)
y_pred_rfc=rfc.predict(X_test)
y_pred_rfc
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([1, 0, 0, ..., 0, 1, 1])

# %%
from sklearn.metrics import *
print('confusion matrix is' ,confusion_matrix(y_test,y_pred_rfc))
print('Precision is',precision_score(y_test,y_pred_rfc))
print('recall is', recall_score(y_test,y_pred_rfc))
print('accuracy is',accuracy_score(y_test,y_pred_rfc))
print('f1 score is',f1_score(y_test,y_pred_rfc))
Accuracy_values.append({'Random Forest':accuracy_score(y_test,y_pred_rfc)})
fscore.append({'Random Forest':f1_score(y_test,y_pred_rfc)})
# Out:
# confusion matrix is [[1181    0]
#  [   0 1257]]
# Precision is 1.0
# recall is 1.0
# accuracy is 1.0
# f1 score is 1.0

# %%
#DECISION TREE

from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(X_train,y_train)
y_pred_dtc=dtc.predict(X_test)
y_pred_dtc
# Out:
# array([1, 0, 0, ..., 0, 1, 1])

# %%
from sklearn.metrics import *
print('confusion matrix is' ,confusion_matrix(y_test,y_pred_dtc))
print('Precision is',precision_score(y_test,y_pred_dtc))
print('recall is', recall_score(y_test,y_pred_dtc))
print('accuracy is',accuracy_score(y_test,y_pred_dtc))
print('f1 score is',f1_score(y_test,y_pred_dtc))
Accuracy_values.append({'DecisionTree':accuracy_score(y_test,y_pred_dtc)})
fscore.append([{'DecisionTree':f1_score(y_test,y_pred_dtc)}])
# Out:
# confusion matrix is [[1181    0]
#  [   0 1257]]
# Precision is 1.0
# recall is 1.0
# accuracy is 1.0
# f1 score is 1.0

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
classifier= KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
classifier.fit(X_train,y_train)
y_pred_knn=classifier.predict(X_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.metrics import *
print('confusion matrix is' ,confusion_matrix(y_test,y_pred_knn))
print('Precision is',precision_score(y_test,y_pred_knn))
print('recall is', recall_score(y_test,y_pred_knn))
print('accuracy is',accuracy_score(y_test,y_pred_knn))
print('f1 score is',f1_score(y_test,y_pred_knn))
Accuracy_values.append([{'knn':accuracy_score(y_test,y_pred_knn)}])  
fscore.append([{'knn':f1_score(y_test,y_pred_knn)}])
# Out:
# confusion matrix is [[1181    0]
#  [   0 1257]]
# Precision is 1.0
# recall is 1.0
# accuracy is 1.0
# f1 score is 1.0

# %%
Accuracy_values
# Out:
# [{'Logistic': 1.0},
#  {'SVM': 0.9983593109105825},
#  {'Random Forest': 1.0},
#  {'DecisionTree': 1.0},
#  [{'knn': 1.0}]]

# %%
fscore
# Out:
# [{'Logistic': 1.0},
#  {'SVM': 0.9984114376489277},
#  {'Random Forest': 1.0},
#  [{'DecisionTree': 1.0}],
#  [{'knn': 1.0}]]

# %% [markdown]
# Result:

# %%
M=['Logistic','SVM','Random Forest','DecisionTree','KNN']
N=[1,0.998,1,1,1]

# %%
sns.barplot(M,N)
plt.title('Accuracy of Different Models')
plt.xlabel('Model_Names')
plt.ylabel('Accuracy_Values')
# Out:
# Text(0, 0.5, 'Accuracy_Values')

# %% [markdown]
# F1 Score plot

# %%
f1=['Logistic','SVM','Random Forest','DecisionTree','KNN']
f2=[1,0.998,1,1,1]

# %%
sns.barplot(f1,f2)
plt.title('F1 Score of Different Models')
plt.xlabel('Model_Names')
plt.ylabel('F1 Score')
# Out:
# Text(0, 0.5, 'F1 Score')
